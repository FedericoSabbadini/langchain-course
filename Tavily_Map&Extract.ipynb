# %% [markdown]
# # 🗺️ TavilyMap & TavilyExtract Tutorial
#
# > **📚 Part of the LangChain Course: Building AI Agents & RAG Apps**
# > [🎓 Get the full course](https://www.udemy.com/course/langchain/?referralCode=D981B8213164A3EA91AC)
#
#
# This notebook demonstrates two powerful tools from Tavily AI:
# - **TavilyMap**: Automatically discovers and maps website structures
# - **TavilyExtract**: Extracts clean, structured content from web pages
#
# Perfect for documentation scraping, research, and content extraction! 🚀
#
# ---

# %% [markdown]
# ## 📦 Setup & Installation
#
# First, let's install the required packages and set up our environment.

# %%
# Install required packages
# !pip install langchain-tavily certifi

# For pretty printing and visualization
# !pip install rich pandas
# Out:
# Requirement already satisfied: langchain-tavily in /usr/local/lib/python3.12/dist-packages (0.2.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (2026.5.20)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in /usr/local/lib/python3.12/dist-packages (from langchain-tavily) (3.13.5)
# Requirement already satisfied: langchain<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-tavily) (1.3.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.11 in /usr/local/lib/python3.12/dist-packages (from langchain-tavily) (1.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.12/dist-packages (from langchain-tavily) (2.32.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.24.2)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain<2.0.0,>=1.0.0->langchain-tavily) (1.2.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain<2.0.0,>=1.0.0->langchain-tavily) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.8.5)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (2.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.0->langchain<2.0.0,>=1.0.0->langchain-tavily) (4.1.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.0->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.0->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.0->langchain<2.0.0,>=1.0.0->langchain-tavily) (3.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=1.0.0->langchain-tavily) (0.4.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-tavily) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.0->langchain<2.0.0,>=1.0.0->langchain-tavily) (1.12.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (13.9.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich) (2.20.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import asyncio
import os
import ssl
from typing import Any, Dict, List

import certifi
from langchain_tavily import TavilyExtract, TavilyMap
from rich.console import Console
from rich.panel import Panel

# Configure SSL context
ssl_context = ssl.create_default_context(cafile=certifi.where())
os.environ["SSL_CERT_FILE"] = certifi.where()
os.environ["REQUESTS_CA_BUNDLE"] = certifi.where()

# Initialize rich console for pretty printing
console = Console()


print("✅ All imports successful!")
# Out:
# ✅ All imports successful!

# %% [markdown]
# ## 🔑 API Key Setup
#
# You'll need a Tavily API key to use these tools. Get yours at [tavily.com](https://app.tavily.com/home?utm_campaign=eden_marco&utm_medium=socials&utm_source=linkedin).
#
# Set environment variable `TAVILY_API_KEY`

# %%
# Set directly (uncomment and add your key)
# tavily_api_key = "your_tavily_api_key_here"

os.environ["TAVILY_API_KEY"] = "your_tavily_api_key_here"

# %% [markdown]
# ## 🗺️ TavilyMap: Website Structure Discovery
#
# TavilyMap automatically discovers and maps website structures by crawling through links. It's perfect for:
# - Documentation sites
# - Blog archives
# - Knowledge bases
# - Any structured website
#
# ### Key Parameters:
# - `max_depth`: How deep to crawl (default: 3)
# - `max_breadth`: How many links per page (default: 10)
# - `max_pages`: Maximum total pages to discover (default: 100)

# %%
# Initialize TavilyMap with custom settings
tavily_map = TavilyMap(
    max_depth=3,        # Crawl up to 3 levels deep
    max_breadth=15,     # Follow up to 15 links per page
    max_pages=50        # Limit to 50 total pages for demo
)

print("✅ TavilyMap initialized successfully!")
# Out:
# ✅ TavilyMap initialized successfully!

# %% [markdown]
# ### 📊 Demo: Mapping a Documentation Site
#
# Let's map the structure of a popular documentation site. We'll use the FastAPI documentation as an example.

# %%
# Example website to map
demo_url = "https://python.langchain.com/docs/introduction/"

console.print(f"🔍 Mapping website structure for: {demo_url}", style="bold blue")
console.print("This may take a moment...")

# Map the website structure
site_map = tavily_map.invoke(demo_url)

# Display results
urls = site_map.get('results', [])
console.print(f"\n✅ Successfully mapped {len(urls)} URLs!", style="bold green")

# Show first 10 URLs as examples
console.print("\n📋 Discovered URLs:", style="bold yellow")
for i, url in enumerate(urls, 1):
    console.print(f"  {i:2d}. {url}")

if len(urls) > 10:
    console.print(f"  ... and {len(urls) - 50} more URLs")
# Out:
# 🔍 Mapping website structure for: https://python.langchain.com/docs/introduction/
# This may take a moment...
# ✅ Successfully mapped 66 URLs!
# 📋 Discovered URLs:
#    1. https://python.langchain.com/docs/introduction
#    2. https://policies.google.com/privacy
#    3. https://adssettings.google.com/
#    4. https://langchain.com/careers
#    5. https://github.com/pricing
#    6. https://atom.io/
#    7. https://smith.langchain.com/
#    8. https://support.github.com/
#    9. https://github.com/enterprise
#   10. https://github.com/sponsors
#   11. https://github.com/langchain-ai
#   12. https://github.com/why-github
#   13. https://js.monitor.azure.com/
#   14. https://stats.wp.com/
#   15. https://js.stripe.com/v3
#   16. https://status.smith.langchain.com/
#   17. https://trust.langchain.com/
#   18. https://www.electronjs.org/
#   19. https://docs.github.com/
#   20. https://www.gstatic.com/
#   21. https://x.com/LangChain
#   22. https://www.githubstatus.com/
#   23. https://github.com/
#   24. https://github.com/topics
#   25. https://desktop.github.com/
#   26. https://about.google/
#   27. https://www.langchain.com/
#   28. https://academy.langchain.com/
#   29. https://github.com/team
#   30. https://github.com/security
#   31. https://skills.github.com/
#   32. https://www.youtube.com/@LangChain
#   33. https://github.blog/
#   34. https://services.github.com/
#   35. https://docs.langchain.com/
#   36. https://chat.langchain.com/
#   37. https://support.langchain.com/
#   38. https://github-cloud.s3.amazonaws.com/
#   39. https://v0.wordpress.com/
#   40. https://github.githubassets.com/
#   41. https://github.com/events
#   42. https://github.com/trending
#   43. https://blog.langchain.com/
#   44. https://policies.google.com/terms
#   45. https://langchain.com/
#   46. https://github.com/solutions
#   47. https://github.community/
#   48. https://forum.langchain.com/
#   49. https://changelog.langchain.com/
#   50. https://github.com/premium-support
#   51. https://interrupt.langchain.com/
#   52. https://www.langchain.com/langgraph
#   53. https://github.com/solutions/executive-insights
#   54. https://policies.google.com/technologies/partner-sites
#   55. https://github.com/solutions/industry
#   56. https://www.linkedin.com/company/langchain
#   57. https://github.com/sponsors/explore
#   58. https://policies.google.com/technologies/cookies
#   59. https://github.com/security/advanced-security
#   60. https://docs.langchain.com/langsmith/home
#   61. https://github.com/topics/cli
#   62. https://github.com/topics/go
#   63. https://github.com/topics/api
#   64. https://policies.google.com/technologies/ads
#   65. https://docs.langchain.com/oss/python/deepagents/overview
#   66. https://policies.google.com/privacy?hl=en-US
#   ... and 16 more URLs

# %% [markdown]
# ## 🔍 TavilyExtract: Clean Content Extraction
#
# TavilyExtract takes URLs and returns clean, structured content without ads, navigation, or other noise. Perfect for:
# - Documentation processing
# - Content analysis
# - Research and data collection
# - Building knowledge bases
#
# ### Key Features:
# - Removes HTML markup and navigation
# - Extracts main content only
# - Handles JavaScript-rendered content
# - Batch processing support

# %%
# Initialize TavilyExtract
tavily_extract = TavilyExtract()

print("✅ TavilyExtract initialized successfully!")
# Out:
# ✅ TavilyExtract initialized successfully!

# %% [markdown]
# ### 📄 Demo: Extracting Content from URLs
#
# Let's extract clean content from some of the URLs we discovered earlier.

# %%
# Select a few interesting URLs for extraction
sample_urls = [urls[15]]  # Take first 5 URLs
console.print(f"📚 Extracting content from {len(sample_urls)} URLs...", style="bold blue")

# Extract content
extraction_result = await tavily_extract.ainvoke(input={"urls": sample_urls})

# Display results
extracted_docs = extraction_result.get('results', [])
console.print(f"\n✅ Successfully extracted {len(extracted_docs)} documents!", style="bold green")

# Show summary of each extracted document
for i, doc in enumerate(extracted_docs, 1):
    url = doc.get('url', 'Unknown')
    content = doc.get('raw_content', '')

    # Create a panel for each document
    panel_content = f"""URL: {url}
Content Length: {len(content):,} characters
Preview: {content}..."""

    console.print(Panel(panel_content, title=f"Document {i}", border_style="blue"))
    print()  # Add spacing
# Out:
# 📚 Extracting content from 1 URLs...
# ✅ Successfully extracted 1 documents!
# ╭────────────────────────────────────────────────── Document 1 ───────────────────────────────────────────────────╮
# │ URL: https://status.smith.langchain.com/                                                                        │
# │ Content Length: 1,099 characters                                                                                │
# │ Preview: [Report a problem](mailto:support@langchain.dev)Subscribe to updates                                   │
# │                                                                                                                 │
# │ LangSmith US                                                                                                    │
# │                                                                                                                 │
# │ - We’re fully operational                                                                                       │
# │                                                                                                                 │
# │ We’re not aware of any issues affecting our systems.                                                            │
# │                                                                                                                 │
# │ ## System status                                                                                                │
# │                                                                                                                 │
# │ Feb 2026-May 2026                                                                                               │
# │                                                                                                                 │
# │ ### LangSmith Application                                                                                       │
# │                                                                                                                 │
# │ 99.84% uptime                                                                                                   │
# │                                                                                                                 │
# │ ### LangSmith Application                                                                                       │
# │                                                                                                                 │
# │ ### LangSmith API                                                                                               │
# │                                                                                                                 │
# │ 98.48% uptime                                                                                                   │
# │                                                                                                                 │
# │ ### LangSmith API                                                                                               │
# │                                                                                                                 │
# │ ### LangSmith Run Ingestion                                                                                     │
# │                                                                                                                 │
# │ 100% uptime                                                                                                     │
# │                                                                                                                 │
# │ ### LangSmith Run Ingestion                                                                                     │
# │                                                                                                                 │
# │ ### LangSmith Deployments Control Plane                                                                         │
# │                                                                                                                 │
# │ 99.97% uptime                                                                                                   │
# │                                                                                                                 │
# │ ### LangSmith Deployments Control Plane                                                                         │
# │                                                                                                                 │
# │ ### LangSmith Deployments Data Plane                                                                            │
# │                                                                                                                 │
# │ 100% uptime                                                                                                     │
# │                                                                                                                 │
# │ ### LangSmith Deployments Data Plane                                                                            │
# │                                                                                                                 │
# │ ### LangSmith Billing                                                                                           │
# │                                                                                                                 │
# │ 100% uptime                                                                                                     │
# │                                                                                                                 │
# │ ### LangSmith Billing                                                                                           │
# │                                                                                                                 │
# │ ### LangSmith PromptHub                                                                                         │
# │                                                                                                                 │
# │ 100% uptime                                                                                                     │
# │                                                                                                                 │
# │ ### LangSmith PromptHub                                                                                         │
# │                                                                                                                 │
# │ ### LangSmith Fleet                                                                                             │
# │                                                                                                                 │
# │ 100% uptime                                                                                                     │
# │                                                                                                                 │
# │ ### LangSmith Fleet                                                                                             │
# │                                                                                                                 │
# │ ### LangSmith Sandboxes                                                                                         │
# │                                                                                                                 │
# │ 99.99% uptime                                                                                                   │
# │                                                                                                                 │
# │ ### LangSmith Sandboxes                                                                                         │
# │                                                                                                                 │
# │ ## Calendar                                                                                                     │
# │                                                                                                                 │
# │ May 2026                                                                                                        │
# │                                                                                                                 │
# │ Loading...                                                                                                      │
# │                                                                                                                 │
# │ M                                                                                                               │
# │                                                                                                                 │
# │ T                                                                                                               │
# │                                                                                                                 │
# │ W                                                                                                               │
# │                                                                                                                 │
# │ T                                                                                                               │
# │                                                                                                                 │
# │ F                                                                                                               │
# │                                                                                                                 │
# │ S                                                                                                               │
# │                                                                                                                 │
# │ S                                                                                                               │
# │                                                                                                                 │
# │ Powered by                                                                                                      │
# │                                                                                                                 │
# │ Looking for the EU status page? Find it here: <https://eu.status.smith.langchain.com>                           │
# │                                                                                                                 │
# │ [Privacy policy](https://www.langchain.com/privacy-policy)                                                      │
# │ [Terms of service](https://www.langchain.com/terms-of-service)...                                               │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### ⚡ Batch Processing Demo
#
# For larger datasets, we can process URLs in batches to optimize performance and handle rate limits.

# %%
def chunk_urls(urls: List[str], chunk_size: int = 3) -> List[List[str]]:
    """Split URLs into chunks of specified size."""
    chunks = []
    for i in range(0, len(urls), chunk_size):
        chunk = urls[i:i + chunk_size]
        chunks.append(chunk)
    return chunks

async def extract_batch(urls: List[str], batch_num: int) -> List[Dict[str, Any]]:
    """Extract documents from a batch of URLs."""
    try:
        console.print(f"🔄 Processing batch {batch_num} with {len(urls)} URLs", style="blue")
        docs = await tavily_extract.ainvoke(input={"urls": urls})
        results = docs.get('results', [])
        console.print(f"✅ Batch {batch_num} completed - extracted {len(results)} documents", style="green")
        return results
    except Exception as e:
        console.print(f"❌ Batch {batch_num} failed: {e}", style="red")
        return []

# Process a larger set of URLs in batches
url_batches = chunk_urls(urls[:9], chunk_size=3) # Take first 9 URLs for batch demo, split to batches of 3

console.print(f"📦 Processing 9 URLs in {len(url_batches)} batches", style="bold yellow")

# Process batches concurrently
tasks = [extract_batch(batch, i + 1) for i, batch in enumerate(url_batches)]
batch_results = await asyncio.gather(*tasks)

# Flatten results
all_extracted = []
for batch_result in batch_results:
    all_extracted.extend(batch_result)

console.print(f"\n🎉 Batch processing complete! Total documents extracted: {len(all_extracted)}", style="bold green")
# Out:
# 📦 Processing 9 URLs in 3 batches
# 🔄 Processing batch 1 with 3 URLs
# 🔄 Processing batch 2 with 3 URLs
# 🔄 Processing batch 3 with 3 URLs
# ✅ Batch 1 completed - extracted 3 documents
# ✅ Batch 3 completed - extracted 3 documents
# ✅ Batch 2 completed - extracted 3 documents
# 🎉 Batch processing complete! Total documents extracted: 9

# %% [markdown]
# ## 🎯 Real-World Use Cases
#
# Here are some practical applications of TavilyMap and TavilyExtract:
#
# ### 1. Documentation Scraping
# - Map entire documentation sites
# - Extract clean content for search indexes
# - Build knowledge bases from existing docs
#
# ### 2. Competitive Analysis
# - Map competitor websites
# - Extract product information
# - Monitor content changes
#
# ### 3. Research & Content Collection
# - Gather information from multiple sources
# - Build datasets for analysis
# - Create content archives
#
# ### 4. SEO & Site Analysis
# - Discover all pages on a site
# - Analyze content structure
# - Identify content gaps

# %% [markdown]
# ## 🎯 Conclusion
#
# This tutorial demonstrated the power of TavilyMap and TavilyExtract for automated web content discovery and extraction:
#
# ### Key Takeaways:
#
# 1. **TavilyMap** is perfect for:
#    - Discovering website structures
#    - Finding all pages on a site
#    - Site auditing
#
# 2. **TavilyExtract** excels at:
#    - Clean content extraction
#    - Removing HTML noise
#    - Batch processing
#    - Structured data collection
#
# 3. **Combined** they enable:
#    - Complete documentation scraping
#    - Automated content pipelines
#    - Knowledge base creation
#    - Research automation
#
# ### Next Steps:
# - Integrate with vector databases for semantic search
# - Add content filtering and classification
# - Build monitoring systems for content changes
# - Create automated reporting dashboards
#
# ---
#
# **Happy scraping!** 🚀
